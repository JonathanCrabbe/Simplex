# %% [markdown]
# # Run Simplex for time series RNN

# %% [markdown]
# ### Imports

# %%
import os
import pickle as pkl
import sys
from random import random

import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

from simplexai.experiments.time_series_prostate_cancer import (
    TimeSeriesProstateCancerDataset,
    load_time_series_prostate_cancer,
)
from simplexai.explainers.simplex import Simplex
from simplexai.models.recurrent_neural_net import MortalityGRU

# %% [markdown]
# ### Load the prostate cancer time series data from file

# %%
def load_data(random_seed=42, corpus_size=100, batch_size=50):

    # LOAD DATA from file
    (
        X,
        y,
        feature_names,
        max_time_points,
        rescale_dict,
    ) = load_time_series_prostate_cancer()

    # Get data into shape and produce corpus
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=random_seed, stratify=y
    )

    print(f"Train set contains {len(y_train)} records")
    print(f"Test set contains {len(y_test)} records")
    print(f"{sum(y_train == 1)} training records with a label of 1")
    print(f"{sum(y_train == 0)} training records with a label of 0")
    print(f"{sum(y_test == 1)} test records with a label of 1")
    print(f"{sum(y_test == 0)} test records with a label of 0")

    class_imbalance_weighting = sum(y_train == 0) / len(y_train)

    train_data = TimeSeriesProstateCancerDataset(X_train, y_train)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    test_data = TimeSeriesProstateCancerDataset(X_test, y_test)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)
    test_examples = enumerate(test_loader)
    batch_id_test, (test_inputs, test_targets) = next(test_examples)

    corpus_loader = DataLoader(train_data, batch_size=corpus_size, shuffle=False)
    corpus_examples = enumerate(corpus_loader)
    batch_id_corpus, (corpus_inputs, corpus_targets) = next(corpus_examples)

    input_baseline = torch.mean(torch.mean(corpus_inputs, 1), 0).expand(
        100, max_time_points, -1
    )  # Baseline tensor of the same shape as corpus_inputs

    return (
        train_loader,
        test_loader,
        corpus_inputs,
        corpus_targets,
        test_inputs,
        test_targets,
        max_time_points,
        feature_names,
        class_imbalance_weighting,
        input_baseline,
        rescale_dict,
    )


# LOAD data
batch_size = 50
corpus_size = 100

(
    train_loader,
    test_loader,
    corpus_inputs,
    corpus_targets,
    test_inputs,
    test_targets,
    max_time_points,
    feature_names,
    class_imbalance_weighting,
    input_baseline,
    rescale_dict,
) = load_data(random_seed=5, corpus_size=corpus_size, batch_size=batch_size)
# Out:
# Train set contains 438 records
# Test set contains 147 records
# 75 training records with a label of 1
# 363 training records with a label of 0
# 25 test records with a label of 1
# 122 test records with a label of 0

# %% [markdown]
# ### Get trained mortality model
#
# Use the boolean variable `train_model` to either train a new model or load a pre-trained model from file.

# %%
def load_trained_model(model, trained_model_state_path):
    model.load_state_dict(torch.load(trained_model_state_path))
    # model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    model.eval()
    return model


# Get a trained model
save_path = os.path.abspath(
    f"../demonstrator/resources/trained_models/RNN/Time series Prostate Cancer/"
)
cv = 1
# Train model if required
train_model = False

if train_model:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Define parameters
    n_epoch_model = 600
    log_interval = 3
    weight_decay = 1e-6

    # Create the model
    classifier = MortalityGRU(
        input_dim=len(feature_names),
        hidden_dim=5,
        output_dim=1,
        n_layers=1,
    )
    print(classifier)
    classifier.to(device)
    class_weights = torch.FloatTensor([class_imbalance_weighting]).to(device)
    criterion = nn.BCELoss(weight=class_weights)
    optimizer = optim.Adam(classifier.parameters(), weight_decay=weight_decay)

    # Train the model
    print(100 * "-" + "\n" + "Now fitting the model. \n" + 100 * "-")
    train_losses = []
    train_counter = []
    test_losses = []

    def train(epoch):
        correct = 0
        correct_0 = 0
        correct_1 = 0
        num_targets_0 = 0
        num_targets_1 = 0

        classifier.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            data = data.to(device)
            output = classifier(data)
            target = target.type(torch.LongTensor).unsqueeze(1).to(device)
            optimizer.zero_grad()
            loss = criterion(output, target.float())
            loss.backward()
            optimizer.step()

            train_roc_score = roc_auc_score(
                target.cpu().detach(), output.cpu().detach()
            )
            pred = output.round()
            num_targets_0 += len((target[target == 0]))
            num_targets_1 += len((target[target == 1]))
            correct_0 += float((pred[target == 0] == target[target == 0]).sum())
            correct_1 += float((pred[target == 1] == target[target == 1]).sum())
            correct += float((pred == target).sum())
            if batch_idx % log_interval == 0:
                train_losses.append(loss.item())
                train_counter.append(
                    (batch_idx * 128) + ((epoch - 1) * len(train_loader.dataset))
                )

        print(
            "TRAINING:\n"
            f"correct: {correct}/{len(train_loader.dataset)} ({100. * correct / len(train_loader.dataset):.0f}%)\n"
            f"correct 0s: {correct_0}/{num_targets_0} ({100. * correct_0 / num_targets_0:.0f}%)\n"
            f"correct 1s: {correct_1}/{num_targets_1} ({100. * correct_1 / num_targets_1:.0f}%)\n"
            f"Training set: Avg. loss: {loss:.4f}, ROC AUC score: {train_roc_score:.4f}"
        )

    def test():
        classifier.eval()
        test_loss = 0
        correct = 0
        correct_0 = 0
        correct_1 = 0
        num_targets_0 = 0
        num_targets_1 = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(test_loader):
                data = data.to(device)
                output = classifier(data)
                target = target.type(torch.LongTensor).unsqueeze(1).to(device)
                test_loss += criterion(output, target.float()).item()
                pred = output.round()

                test_roc_score = roc_auc_score(target.cpu(), output.cpu())
                num_targets_0 += len((target[target == 0]))
                num_targets_1 += len((target[target == 1]))
                correct_0 += float((pred[target == 0] == target[target == 0]).sum())
                correct_1 += float((pred[target == 1] == target[target == 1]).sum())
                correct += float((pred == target).sum())

        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        print(
            "TESTING:\n"
            f"correct: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f})%\n"
            f"correct 0s: {correct_0}/{num_targets_0} ({100. * correct_0 / num_targets_0:.0f})%\n"
            f"correct 1s: {correct_1}/{num_targets_1} ({100. * correct_1 / num_targets_1:.0f})%\n"
            f"Test set:     Avg. loss: {test_loss:.4f}, ROC AUC score: {test_roc_score:.4f}"
        )

    print("Pre-training test.")
    test()
    print("\n\n")
    for epoch in range(1, n_epoch_model + 1):
        print(f"\nepoch: {epoch}")
        train(epoch)
        test()
        torch.save(
            classifier.state_dict(),
            os.path.join(save_path, f"model_cv{cv}.pth"),
        )
        torch.save(
            optimizer.state_dict(),
            os.path.join(save_path, f"optimizer_cv{cv}.pth"),
        )

# Get a trained model
model = MortalityGRU(
    input_dim=len(feature_names),
    hidden_dim=5,
    output_dim=1,
    n_layers=1,
)  # Model should have the BlackBox interface
TRAINED_MODEL_STATE_PATH = os.path.join(save_path, f"model_cv{cv}.pth")
load_trained_model(model, TRAINED_MODEL_STATE_PATH)

# Compute corpus and test model predictions
corpus_predictions = model.forward(corpus_inputs).detach().round()
test_predictions = model.forward(test_inputs).detach().round()

# %% [markdown]
# ### Define function for sorting examples to match the sorted output from jacobian decomposition

# %%
# sort order function for decomposition
def apply_sort_order(in_list, sort_order):
    if isinstance(in_list, list):
        return [in_list[idx] for idx in sort_order]
    if torch.is_tensor(in_list):
        return [in_list.numpy()[idx] for idx in sort_order]

# %% [markdown]
# ### Fit SimplEx

# %%
# Fit SimplEx
# Compute the corpus and test latent representations
corpus_latents = model.latent_representation(corpus_inputs).detach()
test_latents = model.latent_representation(test_inputs).detach()
# Initialize SimplEX, fit it on test examples
simplex = Simplex(corpus_examples=corpus_inputs, corpus_latent_reps=corpus_latents)
simplex.fit(
    test_examples=test_inputs,
    n_epoch=50000,
    test_latent_reps=test_latents,
    reg_factor=0,
)
# Out:
# Weight Fitting Epoch: 10000/50000 ; Error: 0.0823 ; Regulator: 25.6 ; Reg Factor: 0
# Weight Fitting Epoch: 20000/50000 ; Error: 0.00583 ; Regulator: 19.6 ; Reg Factor: 0
# Weight Fitting Epoch: 30000/50000 ; Error: 0.00413 ; Regulator: 18.2 ; Reg Factor: 0
# Weight Fitting Epoch: 40000/50000 ; Error: 0.00411 ; Regulator: 17 ; Reg Factor: 0
# Weight Fitting Epoch: 50000/50000 ; Error: 0.00411 ; Regulator: 16.2 ; Reg Factor: 0

# %% [markdown]
# ### Compute the SimplEx decomposition for test patient i

# %%
# Compute the Integrated Jacobian for a particular example
i = 1
simplex.jacobian_projection(test_id=i, model=model, input_baseline=input_baseline)
result, sort_order = simplex.decompose(i, return_id=True)

# %% [markdown]
# ### Display Test Patient
# Use the variable `test_time_steps_to_display` to change the number of time steps is the displayed output. A value of 50 or greater will ensure all available time points are displayed.

# %%
# set up dataframes
pd.set_option("display.max_columns", None)
test_time_steps_to_display = 3

# Test patient
test_patient_last_time_step_idx = (
    simplex.test_examples[i][
        ~np.all(simplex.test_examples[i].numpy() == 0, axis=1)
    ].shape[0]
    - 1
)
if (test_patient_last_time_step_idx + 1) - test_time_steps_to_display < 0:
    test_time_steps_to_display = test_patient_last_time_step_idx + 1

test_patient_df = pd.DataFrame(
    simplex.test_examples[i][
        test_patient_last_time_step_idx
        - (test_time_steps_to_display - 1) : test_patient_last_time_step_idx
        + 1,
        :,
    ].numpy(),
    columns=feature_names,
    index=[
        f"(t_max) - {i}" if i != 0 else "(t_max)"
        for i in reversed(range(test_time_steps_to_display))
    ],
)
display(test_patient_df.transpose())
# Out:
#                                               (t_max) - 2  (t_max) - 1  \
# Exact age at diagnosis                           0.107004     0.107004
# Number of negative biopsies before diagnosis     0.000000     0.000000
# Number of MRI-visible lesions                    0.000000     0.000000
# Days since diagnosis.3                           0.436568     0.436568
# Days Since Diagnosis                             0.386841     0.422384
# Repeat PSA                                       0.071806     0.088701
# Repeat Biopsy Core Total                         0.313726     0.313726
# Repeat Biopsy Core Positive                      0.333333     0.333333
# Repeat MRI Volume                                0.102222     0.102222
# Repeat MRI PSAd                                  0.190955     0.190955
# Repeat Biopsy Primary Gleason_3.0                0.000000     0.000000
# Repeat Biopsy Secondary Gleason_3.0              1.000000     1.000000
# Repeat Biopsy Secondary Gleason_4.0              0.000000     0.000000
# Repeat Biopsy Grade Group_1.0                    1.000000     1.000000
# Repeat Biopsy Grade Group_2.0                    0.000000     0.000000
# Repeat MRI PRECISE Scoring_1.0                   0.000000     0.000000
# Repeat MRI PRECISE Scoring_2.0                   1.000000     1.000000
# Repeat MRI PRECISE Scoring_3.0                   0.000000     0.000000
# Repeat MRI PRECISE Scoring_4.0                   0.000000     0.000000
# Repeat MRI Stage_0.0                             0.000000     0.000000
# Repeat MRI Stage_1.0                             1.000000     1.000000
# Repeat MRI Stage_2.0                             0.000000     0.000000
# Ethnicity_0.0                                    0.000000     0.000000
# Ethnicity_1.0                                    1.000000     1.000000
# Family History of Prostate Cancer_0.0            0.000000     0.000000
# Family History of Prostate Cancer_1.0            1.000000     1.000000
# CPG_1.0                                          1.000000     1.000000
# CPG_2.0                                          0.000000     0.000000
# PI-RADS score_1.0                                1.000000     1.000000
# PI-RADS score_2.0                                0.000000     0.000000
# PI-RADS score_3.0                                0.000000     0.000000
# PI-RADS score_4.0                                0.000000     0.000000
# PI-RADS score_5.0                                0.000000     0.000000
# STRATCANS (simplified)_1.0                       1.000000     1.000000
# STRATCANS (simplified)_2.0                       0.000000     0.000000
# STRATCANS (simplified)_3.0                       0.000000     0.000000
#
#                                                (t_max)
# Exact age at diagnosis                        0.107004
# Number of negative biopsies before diagnosis  0.000000
# Number of MRI-visible lesions                 0.000000
# Days since diagnosis.3                        0.436568
# Days Since Diagnosis                          0.437593
# Repeat PSA                                    0.101901
# Repeat Biopsy Core Total                      0.313726
# Repeat Biopsy Core Positive                   0.333333
# Repeat MRI Volume                             0.102222
# Repeat MRI PSAd                               0.190955
# Repeat Biopsy Primary Gleason_3.0             0.000000
# Repeat Biopsy Secondary Gleason_3.0           1.000000
# Repeat Biopsy Secondary Gleason_4.0           0.000000
# Repeat Biopsy Grade Group_1.0                 1.000000
# Repeat Biopsy Grade Group_2.0                 0.000000
# Repeat MRI PRECISE Scoring_1.0                0.000000
# Repeat MRI PRECISE Scoring_2.0                1.000000
# Repeat MRI PRECISE Scoring_3.0                0.000000
# Repeat MRI PRECISE Scoring_4.0                0.000000
# Repeat MRI Stage_0.0                          0.000000
# Repeat MRI Stage_1.0                          1.000000
# Repeat MRI Stage_2.0                          0.000000
# Ethnicity_0.0                                 0.000000
# Ethnicity_1.0                                 1.000000
# Family History of Prostate Cancer_0.0         0.000000
# Family History of Prostate Cancer_1.0         1.000000
# CPG_1.0                                       1.000000
# CPG_2.0                                       0.000000
# PI-RADS score_1.0                             1.000000
# PI-RADS score_2.0                             0.000000
# PI-RADS score_3.0                             0.000000
# PI-RADS score_4.0                             0.000000
# PI-RADS score_5.0                             0.000000
# STRATCANS (simplified)_1.0                    1.000000
# STRATCANS (simplified)_2.0                    0.000000
# STRATCANS (simplified)_3.0                    0.000000

# %% [markdown]
# ### Display Corpus decomposition and importances
#
# Define styling functions for displaying dataframe.
#
# Define an `example_importance_threshold` to see all the members of the corpus that have an importance above that certain value and
# `corpus_time_steps_to_display` to set the number of time steps to include in the output.

# %%
def df_values_to_colors(df):
    """Gets color values based in values relative to all other values in df."""

    min_val = np.nanmin(df.values)
    max_val = np.nanmax(df.values)
    for col in df:
        # map values to colors in hex via
        # creating a hex Look up table table and apply the normalized data to it
        norm = mcolors.Normalize(
            vmin=min_val,
            vmax=max_val,
            # vmin=np.nanmin(df[col].values),
            # vmax=np.nanmax(df[col].values),
            clip=True,
        )
        lut = plt.cm.bwr(np.linspace(0.2, 0.75, 256))
        lut = np.apply_along_axis(mcolors.to_hex, 1, lut)
        a = (norm(df[col].values) * 255).astype(np.int16)
        df[col] = lut[a]
    return df


def highlight(x):
    return pd.DataFrame(importance_df_colors.values, index=x.index, columns=x.columns)

# %%
# Corpus of patients

# Variables
example_importance_threshold = 0.1
corpus_time_steps_to_display = 10


# Patient Feature values
last_time_step_idx = [
    result[j][1][~np.all(result[j][1].numpy() == 0, axis=1)].shape[0] - 1
    for j in range(len(result))
]


corpus_dfs = [
    pd.DataFrame(
        result[j][1][idx - (corpus_time_steps_to_display - 1) : idx + 1].numpy(),
        columns=feature_names,
    )
    for j, idx in zip(range(len(result)), last_time_step_idx)
]
for corpus_df in corpus_dfs:
    for col_name, rescale_value in rescale_dict.items():
        corpus_df[col_name] = corpus_df[col_name].apply(lambda x: x * rescale_value)
corpus_data = [
    {
        "feature_vals": corpus_dfs[i].transpose(),
        "Label": apply_sort_order(corpus_targets, sort_order)[i],
        "Prediction": apply_sort_order(corpus_predictions, sort_order)[i],
        "Example Importance": result[i][0],
    }
    for i in range(len(corpus_dfs))
]

# Patient importances
importance_dfs = [
    pd.DataFrame(
        result[j][2][idx - (corpus_time_steps_to_display - 1) : idx + 1].numpy(),
        columns=[f"{col}_fi" for col in feature_names],
    )
    for j, idx in zip(range(len(result)), last_time_step_idx)
]
importance_data = [
    {
        "importance_vals": importance_dfs[i].transpose(),
        "Label": apply_sort_order(corpus_targets, sort_order)[i],
        "Prediction": apply_sort_order(corpus_predictions, sort_order)[i],
        "Example Importance": result[i][0],
    }
    for i in range(len(corpus_dfs))
]

corpus_data = [
    example
    for example in corpus_data
    if example["Example Importance"] >= example_importance_threshold
]
importance_data = [
    example
    for example in importance_data
    if example["Example Importance"] >= example_importance_threshold
]

for example_i in range(len(corpus_data)):
    if (last_time_step_idx[example_i] + 1) - corpus_time_steps_to_display < 0:
        corpus_time_steps_to_display = last_time_step_idx[example_i] + 1
    importance_df_colors = df_values_to_colors(
        importance_data[example_i]["importance_vals"].copy()
    )
    importance_df_colors = importance_df_colors.applymap(
        lambda x: f"background-color: {x}"
    )
    display_corpus_df = (
        corpus_data[example_i]["feature_vals"]
        .rename(
            columns={
                j: t_val
                for j, t_val in enumerate(
                    [
                        f"(t_max) - {i}" if i != 0 else "(t_max)"
                        for i in reversed(range(corpus_time_steps_to_display))
                    ]
                )
            }
        )
        .style.apply(highlight, axis=None)
    )
    print(f"Corpus Example: {example_i}")
    print(f"Example Importance: {corpus_data[example_i]['Example Importance']}")
    display(display_corpus_df)
# Out:
# Corpus Example: 0
# Example Importance: 0.8396381139755249
# <style type="text/css">
# #T_c25f5_row0_col0, #T_c25f5_row3_col9, #T_c25f5_row5_col9, #T_c25f5_row7_col2, #T_c25f5_row8_col0, #T_c25f5_row17_col7, #T_c25f5_row23_col2, #T_c25f5_row24_col0, #T_c25f5_row33_col9 {
#   background-color: #9a9aff;
# }
# #T_c25f5_row0_col1, #T_c25f5_row4_col8, #T_c25f5_row7_col3, #T_c25f5_row8_col1, #T_c25f5_row17_col8, #T_c25f5_row19_col0, #T_c25f5_row23_col3, #T_c25f5_row24_col1 {
#   background-color: #9c9cff;
# }
# #T_c25f5_row0_col2, #T_c25f5_row3_col7, #T_c25f5_row19_col1, #T_c25f5_row23_col8, #T_c25f5_row24_col2, #T_c25f5_row33_col7 {
#   background-color: #a0a0ff;
# }
# #T_c25f5_row0_col3, #T_c25f5_row0_col7, #T_c25f5_row8_col9, #T_c25f5_row11_col2, #T_c25f5_row13_col5, #T_c25f5_row13_col6 {
#   background-color: #a8a8ff;
# }
# #T_c25f5_row0_col4, #T_c25f5_row24_col9 {
#   background-color: #aeaeff;
# }
# #T_c25f5_row0_col5, #T_c25f5_row0_col6, #T_c25f5_row8_col8, #T_c25f5_row19_col2, #T_c25f5_row23_col5, #T_c25f5_row24_col7, #T_c25f5_row33_col5 {
#   background-color: #a6a6ff;
# }
# #T_c25f5_row0_col8, #T_c25f5_row13_col7 {
#   background-color: #acacff;
# }
# #T_c25f5_row0_col9 {
#   background-color: #b0b0ff;
# }
# #T_c25f5_row1_col0, #T_c25f5_row1_col1, #T_c25f5_row1_col2, #T_c25f5_row1_col3, #T_c25f5_row1_col4, #T_c25f5_row1_col5, #T_c25f5_row1_col6, #T_c25f5_row1_col7, #T_c25f5_row1_col8, #T_c25f5_row1_col9, #T_c25f5_row4_col0, #T_c25f5_row4_col1, #T_c25f5_row5_col0, #T_c25f5_row5_col1, #T_c25f5_row5_col2, #T_c25f5_row5_col3, #T_c25f5_row6_col0, #T_c25f5_row6_col1, #T_c25f5_row6_col7, #T_c25f5_row6_col8, #T_c25f5_row9_col0, #T_c25f5_row9_col1, #T_c25f5_row9_col2, #T_c25f5_row12_col8, #T_c25f5_row14_col9, #T_c25f5_row16_col2, #T_c25f5_row16_col3, #T_c25f5_row17_col0, #T_c25f5_row17_col1, #T_c25f5_row17_col2, #T_c25f5_row18_col3, #T_c25f5_row18_col5, #T_c25f5_row18_col6, #T_c25f5_row18_col7, #T_c25f5_row20_col0, #T_c25f5_row22_col0, #T_c25f5_row22_col1, #T_c25f5_row22_col2, #T_c25f5_row22_col3, #T_c25f5_row22_col4, #T_c25f5_row22_col5, #T_c25f5_row22_col6, #T_c25f5_row22_col7, #T_c25f5_row22_col8, #T_c25f5_row22_col9, #T_c25f5_row25_col3, #T_c25f5_row25_col4, #T_c25f5_row25_col5, #T_c25f5_row25_col6, #T_c25f5_row25_col7, #T_c25f5_row25_col8, #T_c25f5_row27_col0, #T_c25f5_row27_col1, #T_c25f5_row27_col2, #T_c25f5_row29_col0, #T_c25f5_row29_col1, #T_c25f5_row29_col2, #T_c25f5_row29_col3, #T_c25f5_row29_col5, #T_c25f5_row29_col6, #T_c25f5_row29_col7, #T_c25f5_row30_col0, #T_c25f5_row30_col1, #T_c25f5_row30_col2, #T_c25f5_row30_col3, #T_c25f5_row31_col0, #T_c25f5_row31_col1, #T_c25f5_row31_col2, #T_c25f5_row31_col3, #T_c25f5_row31_col5, #T_c25f5_row31_col6, #T_c25f5_row31_col7, #T_c25f5_row31_col8, #T_c25f5_row31_col9, #T_c25f5_row32_col0, #T_c25f5_row32_col1, #T_c25f5_row32_col2, #T_c25f5_row32_col7, #T_c25f5_row32_col8, #T_c25f5_row32_col9, #T_c25f5_row33_col0, #T_c25f5_row33_col1, #T_c25f5_row34_col9, #T_c25f5_row35_col0 {
#   background-color: #9292ff;
# }
# #T_c25f5_row2_col0, #T_c25f5_row2_col1, #T_c25f5_row2_col2, #T_c25f5_row2_col3, #T_c25f5_row2_col4, #T_c25f5_row2_col5, #T_c25f5_row2_col6, #T_c25f5_row2_col7, #T_c25f5_row3_col0, #T_c25f5_row5_col4, #T_c25f5_row5_col5, #T_c25f5_row5_col6, #T_c25f5_row5_col7, #T_c25f5_row6_col4, #T_c25f5_row6_col5, #T_c25f5_row6_col6, #T_c25f5_row6_col9, #T_c25f5_row10_col0, #T_c25f5_row10_col1, #T_c25f5_row10_col2, #T_c25f5_row10_col3, #T_c25f5_row10_col4, #T_c25f5_row10_col5, #T_c25f5_row10_col6, #T_c25f5_row10_col7, #T_c25f5_row10_col8, #T_c25f5_row10_col9, #T_c25f5_row12_col0, #T_c25f5_row12_col4, #T_c25f5_row12_col5, #T_c25f5_row12_col6, #T_c25f5_row12_col7, #T_c25f5_row14_col0, #T_c25f5_row14_col1, #T_c25f5_row14_col2, #T_c25f5_row14_col4, #T_c25f5_row14_col5, #T_c25f5_row14_col6, #T_c25f5_row14_col7, #T_c25f5_row14_col8, #T_c25f5_row15_col0, #T_c25f5_row15_col1, #T_c25f5_row15_col2, #T_c25f5_row15_col3, #T_c25f5_row15_col4, #T_c25f5_row15_col5, #T_c25f5_row15_col6, #T_c25f5_row15_col7, #T_c25f5_row15_col8, #T_c25f5_row15_col9, #T_c25f5_row16_col0, #T_c25f5_row16_col1, #T_c25f5_row17_col4, #T_c25f5_row18_col0, #T_c25f5_row18_col1, #T_c25f5_row18_col2, #T_c25f5_row20_col4, #T_c25f5_row20_col5, #T_c25f5_row20_col8, #T_c25f5_row21_col0, #T_c25f5_row21_col1, #T_c25f5_row21_col2, #T_c25f5_row21_col3, #T_c25f5_row21_col4, #T_c25f5_row21_col5, #T_c25f5_row21_col6, #T_c25f5_row21_col7, #T_c25f5_row21_col8, #T_c25f5_row21_col9, #T_c25f5_row23_col9, #T_c25f5_row25_col0, #T_c25f5_row25_col1, #T_c25f5_row25_col2, #T_c25f5_row32_col4, #T_c25f5_row32_col5, #T_c25f5_row32_col6, #T_c25f5_row34_col0, #T_c25f5_row34_col1, #T_c25f5_row34_col2, #T_c25f5_row34_col5, #T_c25f5_row34_col6, #T_c25f5_row34_col7, #T_c25f5_row34_col8 {
#   background-color: #9494ff;
# }
# #T_c25f5_row2_col8, #T_c25f5_row3_col1, #T_c25f5_row5_col8, #T_c25f5_row7_col0, #T_c25f5_row12_col1, #T_c25f5_row17_col5, #T_c25f5_row20_col6, #T_c25f5_row20_col7, #T_c25f5_row23_col0, #T_c25f5_row34_col3, #T_c25f5_row34_col4 {
#   background-color: #9696ff;
# }
# #T_c25f5_row2_col9, #T_c25f5_row3_col2, #T_c25f5_row3_col3, #T_c25f5_row4_col9, #T_c25f5_row7_col1, #T_c25f5_row12_col2, #T_c25f5_row12_col3, #T_c25f5_row14_col3, #T_c25f5_row17_col6, #T_c25f5_row23_col1 {
#   background-color: #9898ff;
# }
# #T_c25f5_row3_col4, #T_c25f5_row4_col4, #T_c25f5_row13_col4, #T_c25f5_row13_col8 {
#   background-color: #b4b4ff;
# }
# #T_c25f5_row3_col5, #T_c25f5_row8_col4, #T_c25f5_row8_col7, #T_c25f5_row17_col9, #T_c25f5_row23_col6, #T_c25f5_row24_col6 {
#   background-color: #a4a4ff;
# }
# #T_c25f5_row3_col6, #T_c25f5_row4_col5, #T_c25f5_row8_col2, #T_c25f5_row8_col5, #T_c25f5_row8_col6, #T_c25f5_row11_col1, #T_c25f5_row23_col7, #T_c25f5_row24_col4, #T_c25f5_row24_col5, #T_c25f5_row33_col6 {
#   background-color: #a2a2ff;
# }
# #T_c25f5_row3_col8, #T_c25f5_row4_col6, #T_c25f5_row4_col7, #T_c25f5_row11_col0, #T_c25f5_row33_col8 {
#   background-color: #9e9eff;
# }
# #T_c25f5_row4_col2, #T_c25f5_row6_col2, #T_c25f5_row9_col4, #T_c25f5_row12_col9, #T_c25f5_row18_col4, #T_c25f5_row18_col8, #T_c25f5_row18_col9, #T_c25f5_row20_col1, #T_c25f5_row20_col2, #T_c25f5_row20_col9, #T_c25f5_row25_col9, #T_c25f5_row27_col3, #T_c25f5_row29_col4, #T_c25f5_row29_col8, #T_c25f5_row29_col9, #T_c25f5_row30_col5, #T_c25f5_row30_col6, #T_c25f5_row30_col7, #T_c25f5_row31_col4, #T_c25f5_row32_col3, #T_c25f5_row33_col2, #T_c25f5_row35_col1, #T_c25f5_row35_col2, #T_c25f5_row35_col4, #T_c25f5_row35_col5, #T_c25f5_row35_col6 {
#   background-color: #9090ff;
# }
# #T_c25f5_row4_col3, #T_c25f5_row6_col3, #T_c25f5_row9_col3, #T_c25f5_row9_col5, #T_c25f5_row9_col6, #T_c25f5_row13_col0, #T_c25f5_row17_col3, #T_c25f5_row20_col3, #T_c25f5_row27_col5, #T_c25f5_row27_col6, #T_c25f5_row27_col7, #T_c25f5_row28_col4, #T_c25f5_row28_col5, #T_c25f5_row30_col8, #T_c25f5_row30_col9, #T_c25f5_row33_col3, #T_c25f5_row35_col7, #T_c25f5_row35_col8 {
#   background-color: #8e8eff;
# }
# #T_c25f5_row7_col4, #T_c25f5_row7_col9, #T_c25f5_row28_col9 {
#   background-color: #8484ff;
# }
# #T_c25f5_row7_col5, #T_c25f5_row7_col6, #T_c25f5_row7_col7, #T_c25f5_row9_col7, #T_c25f5_row13_col1, #T_c25f5_row26_col0, #T_c25f5_row27_col4, #T_c25f5_row27_col8, #T_c25f5_row27_col9, #T_c25f5_row28_col0, #T_c25f5_row28_col7 {
#   background-color: #8a8aff;
# }
# #T_c25f5_row7_col8, #T_c25f5_row9_col8, #T_c25f5_row28_col1 {
#   background-color: #8888ff;
# }
# #T_c25f5_row8_col3, #T_c25f5_row24_col3, #T_c25f5_row24_col8 {
#   background-color: #aaaaff;
# }
# #T_c25f5_row9_col9 {
#   background-color: #8080ff;
# }
# #T_c25f5_row11_col3 {
#   background-color: #bcbcff;
# }
# #T_c25f5_row11_col4 {
#   background-color: #dcdcff;
# }
# #T_c25f5_row11_col5 {
#   background-color: #c6c6ff;
# }
# #T_c25f5_row11_col6 {
#   background-color: #c8c8ff;
# }
# #T_c25f5_row11_col7, #T_c25f5_row13_col9 {
#   background-color: #ceceff;
# }
# #T_c25f5_row11_col8 {
#   background-color: #dadaff;
# }
# #T_c25f5_row11_col9 {
#   background-color: #f0f0ff;
# }
# #T_c25f5_row13_col2, #T_c25f5_row19_col4, #T_c25f5_row26_col1, #T_c25f5_row28_col8 {
#   background-color: #8686ff;
# }
# #T_c25f5_row13_col3, #T_c25f5_row26_col6 {
#   background-color: #7e7eff;
# }
# #T_c25f5_row16_col4 {
#   background-color: #ffe2e2;
# }
# #T_c25

# %% [markdown]
# ### Save the model to file

# %%
# Save SimplEx model
explainer_path = f"../demonstrator/resources/trained_models/RNN/Time series Prostate Cancer/simplex.pkl"

with open(explainer_path, "wb") as f:
    print(f"Saving SimplEx decomposition in {explainer_path}.")

    pkl.dump(simplex, f)
